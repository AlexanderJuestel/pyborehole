# %% [markdown]
# # BoreholeML Parsers

# %% [markdown]
# ## Importing Libraries

# %%
import xml.etree.ElementTree as ET
import pandas as pd
import sys

sys.path.insert(0,'../pybore/')
from boreholeml_parser import parse_xml
# Out:
# C:\Users\ale93371\Anaconda3\envs\pygeomechanical\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\ale93371\Anaconda3\envs\pygeomechanical\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# C:\Users\ale93371\Anaconda3\envs\pygeomechanical\lib\site-packages\numpy\.libs\libopenblas64__v0.3.23-246-g3d31191b-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %% [markdown]
# ## Loading LanguageCode XML

# %%
languagecodes = parse_xml('../data/BoreholeML/LanguageCode.xml')
languagecodes
# Out:
#   Description Identifier  Name KeyID Alternative Identifier Alternative Name
# 0     English        eng  None  None                   None             None
# 1      German        deu  None  None                   None             None

# %% [markdown]
# ## Loading DataBaseSourceList XML

# %%
databases = parse_xml('../data/BoreholeML/DatabaseSourceList.xml')
databases
# Out:
#                                        Description Identifier
# 0          Kohlenwasserstoff-Datenbank Deutschland       KWDB  \
# 1   Datenbank der Bohrungen in Nordrhein-Westfalen       DABO
# 2                      Bohrdatenbank Niedersachsen        BDN
# 3                            Bohrdatenbank Sachsen       BDSN
# 4                     Bohrdatenbank Sachsen-Anhalt      SABIS
# 5                        Bohrdatenbank Brandenburg       BDBB
# 6             Bohrdatenbank Mecklenburg-Vorpommern       LDBS
# 7                 Bohrdatenbank Schleswig-Holstein       BDSH
# 8             Bohrdatenbank der Hansestadt Hamburg       BDHH
# 9                    Bohrdatenbank Rheinland-Pfalz       BDRP
# 10                            Bohrdatenbank Hessen       BDHE
# 11                         Bohrdatenbank Thüringen       BDTH
# 12                  Bodeninformationssystem Bayern     BIS-BY
# 13                 Bohrdatenbank Baden-Württemberg        ADB
# ...

# %% [markdown]
# ## Loading BoreholeStatusList XML

# %%
df = boreholestatuslist = parse_xml('../data/BoreholeML/BoreholeStatusList.xml')
df
# Out:
#                                Description Identifier
# 0   geplant [def] Bohrung im Planungstatus        pla  \
# 1                   angemeldet / angezeigt         ag
# 2                         zur Zeit gebohrt        zbo
# 3                        gebohrt/abgeteuft         bo
# 4                         Funktionsprüfung          f
# 5                                  Wartung          w
# 6                            Regenerierung          r
# 7                               Vertiefung         ti
# 8                                Aufweiten         aw
# 9                               Überbohren        ueb
# 10              Sanierung / Instandsetzung         sa
# 11                                Reinigen        rei
# 12                         Ausbau erneuert         an
# 13               Ausbau teilweise erneuert        atn
# 14            Brunneninstallation erneuert        bin
# 15                   Brunnenstube erneuert        bsn
# ...

# %% [markdown]
# ## Loading SegmentDataQualityList XML

# %%
df = boreholestatuslist = parse_xml('../data/BoreholeML/SegmentDataQualityList.xml')
df
# Out:
#        Description Identifier             Name  KeyID Alternative Identifier
# 0       angenommen          A       angenommen      1                      A  \
# 1  gemessene Daten          G  gemessene Daten      2                      G
#
#   Alternative Name
# 0          assumed
# 1         measured

# %% [markdown]
# ## Loading CodingStandardList

# %%
df = boreholestatuslist = parse_xml('../data/BoreholeML/CodingStandardList.xml')
df
# Out:
#                                          Description Identifier
# 0  Schichterfassungsstandard Symbolschlüssel Geol...        SSG  \
# 1  Schichterfassungsstandard Symbolschlüssel Geol...       SEP2
# 2  Schichterfassungsstandard Symbolschlüssel Geol...       SEP3
# 3                Datenschlüssel für Bohrungen in NRW       DABO
# 4           Standard für erdölgeologischen Austausch        ATS
# 5               Bohrbeschreibungsstandard in Sachsen       UHYD
# 6                Bohrbeschreibungsstandard in Bayern     BIS-BY
# 7                Bohrbeschreibungsstandard in Hessen     BID-HE
# 8           Standard der Erdgas Erdöl GmbH (Gommern)        EEG
#
#                                                 Name  KeyID
# 0  Schichterfassungsstandard Symbolschlüssel Geol...      1  \
# 1  Schichterfassungsstandard Symbolschlüssel Geol...      2
# 2  Schichterfassungsstandard Symbolschlüssel Geol...      3
# 3                Datenschlüssel für Bohrungen in NRW      4
# ...

# %% [markdown]
# ## Loading DrillingMethodList

# %%
df = boreholestatuslist = parse_xml('../data/BoreholeML/DrillingMethodList.xml')
df
# Out:
#                             Description Identifier
# 0          Hand- und Kleinbohrverfahren         HK  \
# 1                           Handbohrung         HB
# 2                       Handdrehbohrung        HDB
# 3                        Handschachtung        HSB
# 4                       Handspülbohrung       HSPB
# ..                                  ...        ...
# 67  Kombi Trocken/Doppelkernspülbohrung        KTD
# 68        Kombi Trocken/Handspülbohrung        KTH
# 69      Kombi Trocken/Rotaryspülbohrung        KTR
# 70              sonstiges Bohrverfahren          W
# 71            unbekanntes Bohrverfahren         UN
#
#                                    Name  KeyID Alternative Identifier
# 0          Hand- und Kleinbohrverfahren      1                     HK  \
# 1                           Handbohrung      2                     HB
# 2                       Handdrehbohrung      3                    HDB
# ...

# %% [markdown]
# ## Loading CasingStringTypeList XML

# %%
df = boreholestatuslist = parse_xml('../data/BoreholeML/CasingStringTypeList.xml')
df
# Out:
#                             Description Identifier
# 0                         Brunnenausbau         ba  \
# 1                     Ausbau Messstelle          M
# 2            Ausbau Explorationsbohrung         Ex
# 3   Ausbau Förderbohrung/Versenkbohrung          F
# 4         Ausbau Förderbohrung (Erdgas)         FG
# 5          Ausbau Förderbohrung (Erdöl)         FE
# 6              Ausbau Forschungsbohrung        FoB
# 7                  Peilrohr / Pegelrohr         pr
# 8                    Inklinometerausbau       inkl
# 9                    Extensometerausbau        ext
# 10                Gleitmikrometerausbau       glei
# 11                            unbekannt         un
# 12                 Ausbau Erdwärmesonde         EW
#
#                                    Name  KeyID Alternative Identifier
# 0                         Brunnenausbau      2                     ba  \
# 1                     Ausbau Messstelle      3                      M
# ...

# %% [markdown]
# ## Loading InstallationElementList XML

# %%
df = boreholestatuslist = parse_xml('../data/BoreholeML/InstallationElementList.xml')
df
# Out:
#                                   Description Identifier
# 0                                Vollwandrohr         RO  \
# 1         Vollwandrohr, torpediert/perforiert       ROTO
# 2                                   Sumpfrohr        ROS
# 3                                   Standrohr       ROST
# 4                                  Futterrohr        ROF
# 5                                     Lotrohr        ROL
# 6                                   Sperrrohr        ROR
# 7                                  Schutzrohr        ROT
# 8                                  Filterrohr         FI
# 9                      Filterrohr, geschlitzt       FISL
# 10                      Langlochschlitzfilter      FISLL
# 11                          Querschlitzfilter      FISLQ
# 12                       Schlitzbrückenfilter      FISLB
# 13                               Winkelfilter        FIW
# 14                 Filterrohr mit Schlammfang       FISG
# ...

# %% [markdown]
# ## Loading InvestigationTypeList XML

# %%
df = boreholestatuslist = parse_xml('../data/BoreholeML/InvestigationTypeList.xml')
df
# Out:
#                                   Description Identifier
# 0                 Bochlochmessung (allgemein)        LOG  \
# 1   bohrlochgeophysikalische Messungen, allg.        BGY
# 2                    Radioaktivitätsmessungen         RA
# 3           elektrische/magnetische Messungen         EM
# 4             seismische/akustische Messungen         AK
# 5                         Temperaturmessungen         TE
# 6                      geometrische Messungen         GM
# 7                      hydraulische Messungen         HY
# 8                    hydrochemische Messungen         HC
# 9                      geochemische Messungen         GC
# 10                    geotechnische Messungen         GT
# 11                         sonstige Messungen         SM
# 12                            Kamerabefahrung         TV
#
#                                          Name  KeyID Alternative Identifier
# 0                 Bochlochmessung (allgemein)      1                    LOG  \
# ...

# %% [markdown]
# ## Loading LastHorizonListXML

# %%
df = boreholestatuslist = parse_xml('../data/BoreholeML/LastHorizonList.xml')
df
# Out:
#             Description Identifier                Name  KeyID
# 0         Phanerozoikum         ph       Phanerozoikum      1  \
# 1            Känozoikum         kz          Känozoikum      2
# 2               Quartär          q             Quartär      3
# 3               Holozän         qh             Holozän      4
# 4           Oberholozän        qho         Oberholozän      5
# ..                  ...        ...                 ...    ...
# 120   Mesoproterozoikum         mp   Mesoproterozoikum    123
# 121  Paläoproterozoikum         pp  Paläoproterozoikum    124
# 122           Archaikum         ar           Archaikum    125
# 123    nicht eingestuft         nb    nicht eingestuft    126
# 124        Terreneuvium        cbT        Terreneuvium    127
#
#     Alternative Identifier  Alternative Name
# 0                       ph       Phanerozoic
# 1                       kz          Cenozoic
# 2                        q        Quaternary
# ...

# %% [markdown]
# ## Loading DrillingPurposeList XML

# %%
df = boreholestatuslist = parse_xml('../data/BoreholeML/DrillingPurposeList.xml')
df
# Out:
#                                           Description Identifier
# 0                         Bodenkundliche Untersuchung        BOD  \
# 1                             Geothermie, Wärmesonden        GTH
# 2                 Geologische Untersuchung, Erkundung          G
# 3                 Geochemische Untersuchung, Analysen         GC
# 4            Geophysikalische Untersuchung, Messungen         GY
# 5     Hydrogeologische Untersuchung, Wasserwirtschaft         HY
# 6                Geotechnische Untersuchung, Baugrund        GTE
# 7                       Altlasten, Umwelt, Deponiebau        AUD
# 8                    Rohstofferkundung und –gewinnung         RO
# 9   Erkundung auf Abbau von Erzen und Industriemin...         EM
# 10          Erkundung auf Abbau von Energierohstoffen         EE
# 11           Erkundung auf Abbau von Steine-und-Erden         SE
# 12                  Erkundung von Untergrundspeichern         UG
# ...

# %% [markdown]
# ## Loading LegalAvailabilityList XML

# %%
df = boreholestatuslist = parse_xml('../data/BoreholeML/LegalAvailabilityList.xml')
df
# Out:
#                                          Description Identifier
# 0                keine Einschränkung der Datenabgabe         KE  \
# 1                                     in Bearbeitung         IB
# 2      nur für den Dienstgebrauch, Weitergabe prüfen        DWP
# 3   nur für den Dienstgebrauch, Weitergabe untersagt        DWU
# 4                                    Verschlusssache          V
# 5  Anfrage beim zuständigen Geologischen Dienst n...         AN
# 6                               Weitergabe untersagt         WU
#
#                                                 Name  KeyID
# 0                keine Einschränkung der Datenabgabe      1  \
# 1                                     in Bearbeitung      2
# 2      nur für den Dienstgebrauch, Weitergabe prüfen      3
# 3   nur für den Dienstgebrauch, Weitergabe untersagt      4
# 4                                    Verschlusssache      5
# 5  Anfrage beim zuständigen Geologischen Dienst n...      6
# ...

# %% [markdown]
# ## Loading TechnicalAvailabilityList XML

# %%
df = boreholestatuslist = parse_xml('../data/BoreholeML/TechnicalAvailabilityList.xml')
df
# Out:
#              Description Identifier                   Name  KeyID
# 0        nicht verfügbar          N        nicht verfügbar      1  \
# 1  vollständig verfügbar          J  vollständig verfügbar      2
# 2    teilweise verfügbar          T    teilweise verfügbar      3
#
#   Alternative Identifier      Alternative Name
# 0                      N         not available
# 1                      J  completely available
# 2                      T      partly available

# %% [markdown]
# ## Loading LocationMethodList XML

# %%
df = boreholestatuslist = parse_xml('../data/BoreholeML/LocationMethodList.xml')
df
# Out:
#                                           Description Identifier
# 0                             aus der Karte abgelesen          K  \
# 1                                 aus DGK 5 abgelesen         K5
# 2                                 aus TK 10 abgelesen        K10
# 3                                 aus TK 25 abgelesen        K25
# 4                                 aus TK 50 abgelesen        K50
# 5                                           geschätzt         GE
# 6                  aus Luftbild/Luftbildplan bestimmt          L
# 7                              geodätisch eingemessen          M
# 8           aus digitalem Landschaftsmodell ermittelt          D
# 9                                 aus DLM 5 ermittelt         D5
# 10                               aus DLM 25 ermittelt        D25
# 11                               aus DLM 50 ermittelt        D50
# 12               differentielle Ortung durch Satellit       DGPS
# ...

# %% [markdown]
# ## Loading LevelMethodList XML

# %%
df = boreholestatuslist = parse_xml('../data/BoreholeML/LevelMethodList.xml')
df
# Out:
#                              Description Identifier
# 0                aus der Karte abgelesen          K  \
# 1   aus Höhenlinien (DGK 5) interpoliert         K5
# 2   aus Höhenlinien (TK 10) interpoliert        K10
# 3   aus Höhenlinien (TK 25) interpoliert        K25
# 4   aus Höhenlinien (TK 50) interpoliert        K50
# 5                              geschätzt         GE
# 6            photogrammetrisch ermittelt         PH
# 7   aus digitalem Geländemodell bestimmt          D
# 8                    aus DGM 5 ermittelt         D5
# 9                   aus DGM 25 ermittelt        D25
# 10                  aus DGM 50 ermittelt        D50
# 11                geodätisch eingemessen          M
# 12  differentielle Ortung durch Satellit       DGPS
# 13                   mit GPS eingemessen        GPS
# 14             mittels Echolot ermittelt         EC
# 15            barometrische Höhenmessung          B
# 16    Fremdangabe (Firma oder Einsender)          F
# ...

# %% [markdown]
# ## Loading RockNameList XML

# %%
df = boreholestatuslist = parse_xml('../data/BoreholeML/RockNameList.xml')
df
# Out:
#                     Description Identifier                        Name  KeyID
# 0                 Lockergestein          l               Lockergestein      1  \
# 1    Sedimentäres Lockergestein         ls  Sedimentäres Lockergestein      2
# 2     Klastisches Lockergestein        lsk   Klastisches Lockergestein      3
# 3     Pelitisches Lockergestein       lpel   Pelitisches Lockergestein      4
# 4                   Ton/Schluff         TU                 Ton/Schluff      5
# ..                          ...        ...                         ...    ...
# 381                     Schacht       Scha                     Schacht    382
# 382                      Tunnel        Tun                      Tunnel    383
# 383          Material unbekannt         ku          Material unbekannt    384
# 384                 Kernverlust         KV                 Kernverlust    385
# 385  Keine Materialbeschreibung       KMat  Keine Materialbeschreibung    386
#
# ...

# %% [markdown]
# ## Loading RockColorList XML

# %%
df = boreholestatuslist = parse_xml('../data/BoreholeML/RockColorList.xml')
df
# Out:
#             Description Identifier                 Name  KeyID
# 0    Value (Helligkeit)          v   Value (Helligkeit)      1  \
# 1                  hell         v1                 hell      2
# 2                dunkel         v2               dunkel      3
# 3   Chroma (Intensität)          c  Chroma (Intensität)      4
# 4               rötlich         c1              rötlich      5
# 5              gelblich         c2             gelblich      6
# 6             bräunlich         c3            bräunlich      7
# 7              grünlich         c4             grünlich      8
# 8              bläulich         c5             bläulich      9
# 9              gräulich         c6             gräulich     10
# 10        Hue (Farbton)          h        Hue (Farbton)     11
# 11              violett         h1              violett     12
# 12                  rot         h2                  rot     13
# 13                 gelb         h3                 gelb     14
# ...

# %% [markdown]
# ## Loading ChronostratigraphyList XML

# %%
df = boreholestatuslist = parse_xml('../data/BoreholeML/ChronoStratigraphyList.xml')
df
# Out:
#             Description Identifier                Name  KeyID
# 0         Phanerozoikum         PH       Phanerozoikum      1  \
# 1            Känozoikum         CZ          Känozoikum      2
# 2               Quartär          Q             Quartär      3
# 3               Holozän         Q2             Holozän      4
# 4            Pleistozän         Q1          Pleistozän      5
# ..                  ...        ...                 ...    ...
# 119  Paläoproterozoikum         PP  Paläoproterozoikum    120
# 120           Archaikum         AR           Archaikum    121
# 121    nicht eingestuft         nb    nicht eingestuft    122
# 122            Gelasium        Q1G            Gelasium    123
# 123              Serie3        Cb3              Serie3    124
#
#     Alternative Identifier  Alternative Name
# 0                       PH       Phanerozoic
# 1                       CZ          Cenozoic
# 2                        Q        Quaternary
# ...

# %% [markdown]
# ## Loading CarbonateContentList XML

# %%
df = boreholestatuslist = parse_xml('../data/BoreholeML/CarbonateContentList.xml')
df
# Out:
#                       Description Identifier                           Name
# 0                    karbonatfrei         c0                   karbonatfrei  \
# 1                  karbonathaltig         c+                 karbonathaltig
# 2                sehr karbonatarm         c1               sehr karbonatarm
# 3                     karbonatarm         c2                    karbonatarm
# 4                  karbonathaltig         c3                 karbonathaltig
# 5            stark karbonathaltig        c++           stark karbonathaltig
# 6                   karbonatreich         c4                  karbonatreich
# 7              sehr karbonatreich         c5             sehr karbonatreich
# 8            extrem karbonatreich         c6           extrem karbonatreich
# 9                        Karbonat         c7                       Karbonat
# 10  keine Angabe / nicht bestimmt         nb  keine Angabe / nicht bestimmt
# ...

# %% [markdown]
# ## Loading CasingMaterialList XML

# %%
df = boreholestatuslist = parse_xml('../data/BoreholeML/CasingMaterialList.xml')
df
# Out:
#                                 Description Identifier
# 0                      Kunststoff allgemein          k  \
# 1                                       PVC        pvc
# 2                                  PVC hart       pvch
# 3                      PVC hart + Kiesbelag       pvck
# 4                                 PVC weich       pvcw
# 5                                    Teflon        tef
# 6              PTFE (Polytetrafluorethylen)       ptfe
# 7                          PE (Polyethylen)         pe
# 8                    HDPE (PE hoher Dichte)       hdpe
# 9                   Polyamide (PA6, 11, 66)         pa
# 10                          PS (Polystyrol)         ps
# 11                Kunstharzpressstoff (OBO)        obo
# 12  Kies-Kunststoff (Willersinn, Kiesgummi)         kk
# 13                                   Metall          m
# 14                          Stahl allgemein         st
# 15                    CrNi- und NiMo-Stähle       crni
# ...

# %% [markdown]
# ## WaterContentList

# %%
df = boreholestatuslist = parse_xml('../data/BoreholeML/WaterContentList.xml')
df
# Out:
#            Description Identifier                 Name  KeyID
# 0              trocken       feu1              trocken      1  \
# 1       schwach feucht       feu2       schwach feucht      2
# 2  feucht (bergfeucht)       feu3  feucht (bergfeucht)      3
# 3         stark feucht       feu4         stark feucht      4
# 4                 nass       feu5                 nass      5
# 5           stark nass       feu6           stark nass      6
#
#   Alternative Identifier Alternative Name
# 0                   feu1              dry
# 1                   feu2   slightly moist
# 2                   feu3      earth moist
# 3                   feu4       very moist
# 4                   feu5              wet
# 5                   feu6         very wet

# %% [markdown]
# ## Loading SamplingPurposeList XML

# %%
df = boreholestatuslist = parse_xml('../data/BoreholeML/SamplingPurposeList.xml')
df
# Out:
#                                           Description Identifier
# 0                           Absolute Altersbestimmung         AA  \
# 1              Bodenkundliche Untersuchung, allgemein         BK
# 2                Geochemische Untersuchung, allgemein         GC
# 3            Geophysikalische Untersuchung, allgemein         GP
# 4      Ingenieurgeologisch/Geotechnische Untersuchung         GT
# 5                     Hydrogeologische Untersuchungen         HY
# 6                     Paläontologische Untersuchungen         PA
# 7   Mineralogische und Petrographische Untersuchungen         MN
# 8       Untersuchungen zur technischen Verwendbarkeit         TV
# 9                    Rohstoffgeologische Untersuchung        ROH
# 10                    Petrophysikalische Untersuchung        SPH
# 11                                 Wasseruntersuchung         WU
# 12                        Archäologische Untersuchung         AR
# ...

# %% [markdown]
# ## Loading SampleTypeList XML

# %%
df = boreholestatuslist = parse_xml('../data/BoreholeML/SampleTypeList.xml')
df
# Out:
#                               Description Identifier
# 0               Gesteinsprobe (allgemein)        prb  \
# 1                   Bohrprobe (allgemein)         bp
# 2                      gestörte Bohrprobe        bpg
# 3                    ungestörte Bohrprobe        bpu
# 4                   orientierte Bohrprobe        bpo
# 5                 Bodenprobe (Bodenkunde)         bo
# 6              gestörte Bodenprobe [Tüte]        bog
# 7   ungestörte Bodenprobe [Stechzylinder]        bou
# 8                   Spülprobe (allgemein)         sp
# 9                            Schlämmprobe        asp
# 10                            Schöpfprobe      prsch
# 11                              Pumpprobe       pump
# 12                            Meißelprobe        pms
# 13                              Bohrklein         bk
# 14                             Drillprobe        bpd
# 15                         Fördergutprobe        fgp
# 16                          Gesteinsprobe         pg
# ...

# %% [markdown]
# ## Loading CompactnessList XML

# %%
df = boreholestatuslist = parse_xml('../data/BoreholeML/CompactnessList.xml')
df
# Out:
#             Description Identifier                  Name  KeyID
# 0           sehr locker        ld1           sehr locker      1  \
# 1       locker gelagert        ld2       locker gelagert      2
# 2  mitteldicht gelagert        ld3  mitteldicht gelagert      3
# 3        dicht gelagert        ld4        dicht gelagert      4
# 4            sehr dicht        ld5            sehr dicht      5
#
#   Alternative Identifier     Alternative Name
# 0                    ld1  very loosely packed
# 1                    ld2       loosely packed
# 2                    ld3  semi-densely packed
# 3                    ld4       densely packed
# 4                    ld5  very densely packed

# %% [markdown]
# ## Loading ConsistencyList XML

# %%
df = boreholestatuslist = parse_xml('../data/BoreholeML/ConsistencyList.xml')
df
# Out:
#   Description Identifier      Name  KeyID Alternative Identifier
# 0     flüssig        flu   flüssig      1                    flu  \
# 1      breiig        bre    breiig      2                    bre
# 2       weich         wh     weich      3                     wh
# 3       steif        stf     steif      4                    stf
# 4    halbfest        hfe  halbfest      5                    hfe
# 5        fest         fe      fest      6                     fe
#
#   Alternative Name
# 0           liquid
# 1            pulpy
# 2             soft
# 3            stiff
# 4       semi-solid
# 5            solid

# %% [markdown]
# ## Loading DrillingToolList XML

# %%
df = boreholestatuslist = parse_xml('../data/BoreholeML/DrillingToolList.xml')
df
# Out:
#                              Description Identifier
# 0                          Kernbohrkrone          K  \
# 1                          Corboritkrone         CS
# 2                           Diamantkrone         KD
# 3                        Hartmetallkrone         KH
# 4                  Hartmetallstufenkrone        KHS
# 5                            Rollenkrone         KR
# 6                            Schrotkrone         KS
# 7                              Hohlkrone        KHO
# 8                              Vollkrone        KVO
# 9                       offene Bohrkrone        KOB
# 10                        Spülbohrmeißel          M
# 11           Blatt-(Fischschwanz-)Meißel         MB
# 12                         Diamantmeißel         MD
# 13                           Düsenmeißel        MDU
# 14                      Düsenblattmeißel         MC
# 15                     Düsenflügelmeißel         MG
# 16                     Düsenrollenmeißel         MP
# ...

# %% [markdown]
# ## Loading ElevationReferenceList

# %%
df = boreholestatuslist = parse_xml('../data/BoreholeML/ElevationReferenceSystemList.xml')
df
# Out:
#                           Description Identifier
# 0                          Normalnull       5783  \
# 1                          Lotmessung       0000
# 2             Neuer Amsterdamer Pegel       5709
# 3  Höhen-Nullpunkt, Kronstedter Pegel       5705
#
#                                  Name  KeyID Alternative Identifier
# 0                          Normalnull      1                   5783  \
# 1                          Lotmessung      3                   0000
# 2             Neuer Amsterdamer Pegel      6                   5709
# 3  Höhen-Nullpunkt, Kronstedter Pegel      7                   5705
#
#                      Alternative Name
# 0                              DHHN92
# 1  Lowest Astronomical Tide till 2005
# 2               NAP height NAP height
# 3                       Baltic height

# %% [markdown]
# ## Loading FillingMaterialList XML

# %%
df = boreholestatuslist = parse_xml('../data/BoreholeML/FillingMaterialList.xml')
df
# Out:
#                     Description Identifier                         Name
# 0                Filtermaterial          F               Filtermaterial  \
# 1                    Filterkies       FKIZ                   Filterkies
# 2             Filterkies/Zement        FKi            Filterkies/Zement
# 3                    Filtersand         FS                   Filtersand
# 4                   Gegenfilter        FGF                  Gegenfilter
# 5    Abdichtungsmaterial/Dämmer          A   Abdichtungsmaterial/Dämmer
# 6                        Packer         AP                       Packer
# 7        Zement/Zementinjektion         AZ       Zement/Zementinjektion
# 8                Portlandzement        APZ               Portlandzement
# 9    Halliburton-Tiefbohrzement        AHZ   Halliburton-Tiefbohrzement
# 10                Spezialzement       ASPZ                Spezialzement
# 11               Tiefbohrzement       ATBZ               Tiefbohrzement
# ...

# %% [markdown]
# ## Loading FlushingTypeList XML

# %%
df = boreholestatuslist = parse_xml('../data/BoreholeML/FlushingTypeList.xml')
df
# Out:
#                                Description Identifier
# 0                            mit Spülhilfe          S  \
# 1                              Luftspülung         LS
# 2                            Schaumspülung         SS
# 3                        Klarwasserspülung         SK
# 4           Klarwasserspülung mit Zusätzen        SKZ
# 5         Klarwasserspülung mit CMC-Zusatz        SKC
# 6     Klarwasserspülung mit Antisol-Zusatz        SKA
# 7   Klarwasserspülung mit sonstigem Zusatz        SKS
# 8                       tonstabile Spülung         ST
# 9                         Bentonit-Spülung         SB
# 10                    Bentonit-CMC-Spülung         SC
# 11                Bentonit-Antisol-Spülung         SA
# 12                     salzstabile Spülung        SSA
# 13                 Kaliumkarbonat-Spülung          KS
# 14                      beschwerte Spülung         BS
# 15                          ohne Spülhilfe         OS
# ...

# %% [markdown]
# ## Loading GenesisList XML

# %%
df = boreholestatuslist = parse_xml('../data/BoreholeML/GenesisList.xml')
df
# Out:
#                     Description Identifier                        Name  KeyID
# 0                    unbestimmt        unb                  unbestimmt      1  \
# 1                   anthropogen       anth                 anthropogen      2
# 2    Sedimentation (sedimentär)        sed  Sedimentation (sedimentär)      8
# 3                     klastisch        kla                   klastisch      9
# 4                       fluvial         fl                     fluvial     10
# ..                          ...        ...                         ...    ...
# 108                     litoral        mlt                     litoral    163
# 109                   brackisch      brack                   brackisch    164
# 110             Süßwassermilieu      suess             Süßwassermilieu    165
# 111                 palustrisch        pal                 palustrisch    166
# 112                agglomeriert       vsag                agglomeriert    167
#
# ...

# %% [markdown]
# ## Loading GeoGenesisList XML

# %%
df = boreholestatuslist = parse_xml('../data/BoreholeML/GeoGenesisList.xml')
df
# Out:
#                                     Description Identifier
# 0                Meeres- und Küstenablagerungen         mk  \
# 1                            Meeresablagerungen          m
# 2                           Tiefseeablagerungen         mp
# 3                          Flachseeablagerungen         mn
# 4    Flachseeablagerungen, gletscherbeeinflusst         mg
# ..                                          ...        ...
# 165                       Künstliche Auffüllung         yf
# 166                     Künstliche Aufschüttung         ys
# 167                                 Plaggenesch        yPg
# 168                             Sandmischkultur        ySm
# 169                       Künstliche Aufspülung         yw
#
#                                            Name  KeyID Alternative Identifier
# 0                Meeres- und Küstenablagerungen      1                     mk  \
# 1                            Meeresablagerungen      2                      m
# ...

# %% [markdown]
# ## Loading GroundwaterobservationTypeList XML

# %%
df = boreholestatuslist = parse_xml('../data/BoreholeML/GroundwaterObservationTypeList.xml')
df
# Out:
#                       Description Identifier                            Name
# 0            Grundwasseranschnitt          A            Grundwasseranschnitt  \
# 1  eingestellter Grundwasserstand          E  eingestellter Grundwasserstand
# 2   allgemeine Grundwassermessung          M   allgemeine Grundwassermessung
# 3    kein Grundwasser angetroffen          N    kein Grundwasser angetroffen
#
#    KeyID Alternative Identifier                       Alternative Name
# 0      1                      A                   groundwater exposure
# 1      2                      E  leveled-out groundwater meter reading
# 2      3                      M      extensive water level measurement
# 3      4                      N             no groundwater encountered

# %% [markdown]
# ## Loading IntervalTypeList XML

# %%
df = boreholestatuslist = parse_xml('../data/BoreholeML/IntervalTypeList.xml')
df
# Out:
#        Description Identifier             Name  KeyID Alternative Identifier
# 0    Einzelschicht         ez    Einzelschicht      1                     ez  \
# 1          Abfolge         ab          Abfolge      2                     ab
# 2  Wechsellagerung         wl  Wechsellagerung      3                     wl
# 3     Zwischenlage         zl     Zwischenlage      4                     zl
# 4       Komponente        kom       Komponente      5                    kom
#
#       Alternative Name
# 0           single bed
# 1     sequence of beds
# 2  alternating bedding
# 3     intercalated bed
# 4            component

# %% [markdown]
# ## Loading MD_CharacterSetCode XML

# %%
df = boreholestatuslist = parse_xml('../data/BoreholeML/MD_CharacterSetCode.xml')
df
# Out:
#                                           Description  Identifier  Name KeyID
# 0   16-bit fixed size Universal Character Set, bas...        ucs2  None  None  \
# 1   32-bit fixed size Universal Character Set, bas...        ucs4  None  None
# 2   7-bit variable size UCS Transfer Format, based...        utf7  None  None
# 3   8-bit variable size UCS Transfer Format, based...        utf8  None  None
# 4   16-bit variable size UCS Transfer Format, base...       utf16  None  None
# 5   ISO/IEC 8859-1, Information technology - 8-bit...   8859part1  None  None
# 6   ISO/IEC 8859-2, Information technology - 8-bit...   8859part2  None  None
# 7   ISO/IEC 8859-3, Information technology - 8-bit...   8859part3  None  None
# 8   ISO/IEC 8859-4, Information technology - 8-bit...   8859part4  None  None
# 9   ISO/IEC 8859-5, Information technology - 8-bit...   8859part5  None  None
# 10  ISO/IEC 8859-6, Information technology - 8-bit...   8859part6  None  None
# ...

# %% [markdown]
# ## Loading RockColorMixtureList XML

# %%
df = boreholestatuslist = parse_xml('../data/BoreholeML/RockColorMixtureList.xml')
df
# Out:
#    Description Identifier         Name  KeyID Alternative Identifier
# 0     gefleckt         fl     gefleckt      1                     fl  \
# 1  gesprenkelt         fp  gesprenkelt      2                     fp
# 2      meliert         fm      meliert      3                     fm
# 3    gestreift         fs    gestreift      4                     fs
# 4      stichig         fi      stichig      5                     fi
# 5   marmoriert         fk   marmoriert      6                     fk
#
#   Alternative Name
# 0         speckled
# 1           dotted
# 2          mottled
# 3          striped
# 4        with hues
# 5          marbled
